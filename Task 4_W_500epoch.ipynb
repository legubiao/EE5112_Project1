# %% [markdown]
# # Task 4: Understand speech recognition and speech-to-text conversion

# %% [markdown]
# ## 1. Design a simple neural network to recognize spoken digits: Free Spoken Digit Dataset contains recordings of spoken digits in wave files at 8kHz. This dataset contains 50 recordings for every 10 digits per every 6 speakers. This dataset in total contains 3000 recordings in English pronunciations.

# %% [markdown]
# ## 2. Design a program to convert the given dataset MP3 file into text. Show your code and results in your report. Program can be done with open-source python libraries, e.g. “speech_recognition” or “pydub”.

# %% [markdown]
# ## 3. Establish your own input dataset, and convert your own speech data into text. For example, by recording:“ I am having fun with human robot interaction class.” Show your code and results in your report.

# %% [markdown]
# ## 5. Write down the problems you encountered during the experiment, the solutions, and your experiences.

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

# 定义数据目录
data_dir = 'dataset_for_task4/free-spoken-digit-dataset/recordings'

# 准备用于存储数据和标签的列表
data = []
labels = []

# 计算全局最大时间帧数
max_time_frames_global = 0

# 遍历数据目录
for filename in os.listdir(data_dir):
    if filename.endswith('.wav'):
        # 解析文件名以获取数字和说话者信息
        digit, speaker, _ = filename.split('_')
        
        # 加载音频文件
        audio_path = os.path.join(data_dir, filename)
        y, sr = librosa.load(audio_path)  # 读取整个音频文件
        
        # 将音频波形转换为频谱图
        D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)

        # 计算当前音频文件的时间帧数
        num_time_frames = D.shape[1]
        max_time_frames_global = max(max_time_frames_global, num_time_frames)
        
        # 存储数据和标签
        data.append(D)
        labels.append(int(digit))
print('全局最大时间帧数：', max_time_frames_global)
# 将所有频谱图调整为全局最大时间帧数
for i in range(len(data)):
    num_frames = data[i].shape[1]
    if num_frames < max_time_frames_global:
        # 使用填充将时间帧数调整为全局最大值
        padding = max_time_frames_global - num_frames
        data[i] = np.pad(data[i], ((0, 0), (0, padding)), mode='constant')

# 将数据和标签转换为NumPy数组
data = np.array(data)
labels = np.array(labels)

# 划分训练集和测试集
# X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
# Out:
# 全局最大时间帧数： 99

# %%
print('数据集大小：', data.shape)
print(labels.shape)
# Out:
# 数据集大小： (1500, 1025, 99)
# (1500,)

# %%
import torch
import torch.nn.functional as F
import torch.utils.data as utils_data
class ConvModule(torch.nn.Module):
    def __init__(self,input_channel=1):
        super(ConvModule, self).__init__()
        
        self.conv = torch.nn.Sequential(
            # (batch_size, input_channel, H, W)->(batch_size, 32, H-2, W-2)
            torch.nn.Conv2d(in_channels=input_channel, out_channels=32, kernel_size=3, stride=1, padding=0),
            torch.nn.BatchNorm2d(32),
            torch.nn.ReLU(inplace=True),
            # (batch_size, 32, H-2, W-2)->(batch_size, 64, H-4, W-4)
            torch.nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=0),
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(inplace=True),
            # (batch_size, 64, H-4, W-4)->(batch_size, 128, H-6, W-6)
            torch.nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=0),
            torch.nn.BatchNorm2d(128),
            torch.nn.ReLU(inplace=True)
        )
        #(128)->(4)
        self.fc = torch.nn.Linear(128, 10)

    def forward(self, X):
        # device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        X=X.unsqueeze(1)
        # X = X.to(device)
        out = self.conv(X)  # (batch_size, 128, H - 6, W - 6)
        # 48-2-2-2=42
        out = F.adaptive_avg_pool2d(out, (1,1))
        # out = F.avg_pool2d(out, 42)  # (batch_size, 128, 1, 1)
        # (batch_size, 128, 1, 1)->(batch_size, 128)
        out = out.squeeze()
        out = self.fc(out)
        return out

# %%
import torch.nn as nn
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ConvModule()
model.to(device)
if torch.cuda.is_available():
    model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
loss_func = nn.CrossEntropyLoss()

# %%
dataset_size, H, W = data.shape
print(data.shape)
print(dataset_size, H, W)
# Out:
# (1500, 1025, 99)
# 1500 1025 99

# %%
dataset = utils_data.TensorDataset(torch.Tensor(data), torch.LongTensor(labels))
split_ratio = 0.8
train_size = int(split_ratio * dataset_size)
test_size = dataset_size - train_size
train_set, test_set = utils_data.random_split(dataset, [train_size, test_size])
train_loader = utils_data.DataLoader(dataset=train_set, batch_size=8, shuffle=True)
test_loader = utils_data.DataLoader(dataset=test_set, batch_size=8, shuffle=True)
print('Data is ready!')
# Out:
# Data is ready!

# %%
import matplotlib.pyplot as plt

# Lists to store training and testing accuracies for each epoch
train_accs = []
test_accs = []

best_accuracy = 0
for epoch in range(500):
    running_loss = 0.0
    train_acc = 0.0
    for step, (batch_image, batch_label) in enumerate(train_loader):
        model.train()
        model = model.to(device)
        batch_image, batch_label = batch_image.to(device), batch_label.to(device)
        batch_output = model(batch_image)
        batch_loss = loss_func(batch_output, batch_label)

        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()

        running_loss += batch_loss.item()

        _, train_predicted = torch.max(batch_output.data, 1)
        train_acc += (train_predicted == batch_label).sum().item()

    train_acc /= train_size
    running_loss /= (step + 1)

    model.eval()
    test_acc = 0.0
    for test_image, test_label in test_loader:
        test_image, test_label = test_image.to(device), test_label.to(device)
        test_output = model(test_image)
        _, predicted = torch.max(test_output.data, 1)
        test_acc += (predicted == test_label).sum().item()
    test_acc /= test_size

    print('epoch={:d}\ttrain loss={:.6f}\ttrain accuracy={:.3f}\ttest accuracy={:.3f}'.format(
        epoch, running_loss, train_acc, test_acc))

    # Append accuracies to the lists
    train_accs.append(train_acc)
    test_accs.append(test_acc)

    if test_acc >= best_accuracy:
        save_path = './task4_trained_models/'
        if not os.path.exists(save_path):
            os.makedirs(save_path)
        torch.save(model.state_dict(), './task4_trained_models/FCNN_model.pkl')
        best_accuracy = test_acc

# Plot the training and testing accuracies
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_accs) + 1), train_accs, label='Train Accuracy')
plt.plot(range(1, len(test_accs) + 1), test_accs, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Testing Accuracies')
plt.grid(True)
plt.show()
# Out:
# epoch=0	train loss=2.291098	train accuracy=0.142	test accuracy=0.110
# epoch=1	train loss=2.257744	train accuracy=0.168	test accuracy=0.153
# epoch=2	train loss=2.239416	train accuracy=0.177	test accuracy=0.093
# epoch=3	train loss=2.217569	train accuracy=0.207	test accuracy=0.117
# epoch=4	train loss=2.186260	train accuracy=0.228	test accuracy=0.197
# epoch=5	train loss=2.167756	train accuracy=0.214	test accuracy=0.173
# epoch=6	train loss=2.134045	train accuracy=0.228	test accuracy=0.220
# epoch=7	train loss=2.122418	train accuracy=0.249	test accuracy=0.243
# epoch=8	train loss=2.088152	train accuracy=0.272	test accuracy=0.120
# epoch=9	train loss=2.066402	train accuracy=0.266	test accuracy=0.207
# epoch=10	train loss=2.065131	train accuracy=0.247	test accuracy=0.257
# epoch=11	train loss=2.040053	train accuracy=0.275	test accuracy=0.160
# epoch=12	train loss=2.029021	train accuracy=0.279	test accuracy=0.133
# epoch=13	train loss=2.006224	train accuracy=0.278	test accuracy=0.203
# epoch=14	train loss=2.005903	train accuracy=0.275	test accuracy=0.307
# epoch=15	train loss=1.999766	train accuracy=0.293	test accuracy=0.240
# epoch=16	train loss=1.988236	train accuracy=0.287	test accuracy=0.243
# epoch=17	train loss=1.980183	train accuracy=0.293	test accuracy=0.117
# epoch=18	train loss=1.957163	train accuracy=0.293	test accuracy=0.290
# epoch=19	train loss=1.954182	train accuracy=0.301	test accuracy=0.217
# epoch=20	train loss=1.925505	train accuracy=0.316	test accuracy=0.243
# epoch=21	train loss=1.931103	train accuracy=0.318	test accuracy=0.190
# epoch=22	train loss=1.931577	train accuracy=0.320	test accuracy=0.223
# epoch=23	train loss=1.912204	train accuracy=0.338	test accuracy=0.127
# epoch=24	train loss=1.910413	train accuracy=0.334	test accuracy=0.333
# epoch=25	train loss=1.902109	train accuracy=0.329	test accuracy=0.200
# epoch=26	train loss=1.880440	train accuracy=0.357	test accuracy=0.133
# epoch=27	train loss=1.864982	train accuracy=0.342	test accuracy=0.243
# epoch=28	train loss=1.837452	train accuracy=0.369	test accuracy=0.383
# epoch=29	train loss=1.830724	train accuracy=0.377	test accuracy=0.327
# epoch=30	train loss=1.820818	train accuracy=0.368	test accuracy=0.397
# epoch=31	train loss=1.830839	train accuracy=0.365	test accuracy=0.263
# epoch=32	train loss=1.818214	train accuracy=0.390	test accuracy=0.093
# epoch=33	train loss=1.777470	train accuracy=0.400	test accuracy=0.267
# epoch=34	train loss=1.776138	train accuracy=0.394	test accuracy=0.280
# epoch=35	train loss=1.761495	train accuracy=0.412	test accuracy=0.170
# epoch=36	train loss=1.778015	train accuracy=0.390	test accuracy=0.237
# epoch=37	train loss=1.717658	train accuracy=0.426	test accuracy=0.190
# epoch=38	train loss=1.686788	train accuracy=0.439	test accuracy=0.420
# epoch=39	train loss=1.672133	train accuracy=0.435	test accuracy=0.430
# epoch=40	train loss=1.659001	train accuracy=0.449	test accuracy=0.170
# epoch=41	train loss=1.644444	train accuracy=0.457	test accuracy=0.110
# epoch=42	train loss=1.644634	train accuracy=0.436	test accuracy=0.277
# epoch=43	train loss=1.633734	train accuracy=0.468	test accuracy=0.420
# epoch=44	train loss=1.624648	train accuracy=0.445	test accuracy=0.477
# epoch=45	train loss=1.593197	train accuracy=0.466	test accuracy=0.460
# epoch=46	train loss=1.557138	train accuracy=0.494	test accuracy=0.377
# epoch=47	train loss=1.541728	train accuracy=0.498	test accuracy=0.427
# epoch=48	train loss=1.524118	train accuracy=0.513	test accuracy=0.370
# epoch=49	train loss=1.545985	train accuracy=0.491	test accuracy=0.437
# epoch=50	train loss=1.509437	train accuracy=0.495	test accuracy=0.483
# epoch=51	train loss=1.533754	train accuracy=0.484	test accuracy=0.313
# epoch=52	train loss=1.505678	train accuracy=0.487	test accuracy=0.507
# epoch=53	train loss=1.495334	train accuracy=0.518	test accuracy=0.553
# epoch=54	train loss=1.452109	train accuracy=0.507	test accuracy=0.447
# epoch=55	train loss=1.440518	train accuracy=0.542	test accuracy=0.540
# epoch=56	train loss=1.442751	train accuracy=0.542	test accuracy=0.410
# epoch=57	train loss=1.430992	train accuracy=0.527	test accuracy=0.280
# epoch=58	train loss=1.435665	train accuracy=0.537	test accuracy=0.280
# epoch=59	train loss=1.433458	train accuracy=0.528	test accuracy=0.403
# epoch=60	train loss=1.399364	train accuracy=0.560	test accuracy=0.330
# epoch=61	train loss=1.379439	train accuracy=0.561	test accuracy=0.253
# epoch=62	train loss=1.407958	train accuracy=0.542	test accuracy=0.487
# epoch=63	train loss=1.365278	train accuracy=0.560	test accuracy=0.410
# epoch=64	train loss=1.356953	train accuracy=0.574	test accuracy=0.583
# epoch=65	train loss=1.342369	train accuracy=0.565	test accuracy=0.473
# epoch=66	train loss=1.330110	train accuracy=0.574	test accuracy=0.593
# epoch=67	train loss=1.330616	train accuracy=0.563	test accuracy=0.173
# epoch=68	train loss=1.348752	train accuracy=0.553	test accuracy=0.620
# epoch=69	train loss=1.296042	train accuracy=0.576	test accuracy=0.453
# epoch=70	train loss=1.285736	train accuracy=0.580	test accuracy=0.283
# epoch=71	train loss=1.288339	train accuracy=0.580	test accuracy=0.607
# epoch=72	train loss=1.276582	train accuracy=0.584	test accuracy=0.390
# epoch=73	train loss=1.272306	train accuracy=0.588	test accuracy=0.303
# epoch=74	train loss=1.258133	train accuracy=0.592	test accuracy=0.637
# epoch=75	train loss=1.251215	train accuracy=0.619	test accuracy=0.287
# epoch=76	train loss=1.242521	train accuracy=0.603	test accuracy=0.343
# epoch=77	train loss=1.221464	train accuracy=0.613	test accuracy=0.620
# epoch=78	train loss=1.224993	train accuracy=0.630	test accuracy=0.357
# epoch=79	train loss=1.220071	train accuracy=0.610	test accuracy=0.347
# epoch=80	train loss=1.216095	train accuracy=0.626	test accuracy=0.250
# epoch=81	train loss=1.201901	train accuracy=0.628	test accuracy=0.370
# epoch=82	train loss=1.209888	train accuracy=0.616	test accuracy=0.150
# epoch=83	train loss=1.201122	train accuracy=0.617	test accuracy=0.230
# epoch=84	train loss=1.160256	train accuracy=0.638	test accuracy=0.143
# epoch=85	train loss=1.174129	train accuracy=0.635	test accuracy=0.290
# epoch=86	train loss=1.178425	train accuracy=0.640	test accuracy=0.693
# epoch=87	train loss=1.138094	train accuracy=0.642	test accuracy=0.690
# epoch=88	train loss=1.156713	train accuracy=0.647	test accuracy=0.247
# epoch=89	train loss=1.146182	train accuracy=0.632	test accuracy=0.227
# epoch=90	train loss=1.142843	train accuracy=0.638	test accuracy=0.610
# epoch=91	train loss=1.129357	train accuracy=0.645	test accuracy=0.740
# epoch=92	train loss=1.109375	train accuracy=0.651	test accuracy=0.203
# epoch=93	train loss=1.109101	train accuracy=0.640	test accuracy=0.373
# epoch=94	train loss=1.118537	train accuracy=0.636	test accuracy=0.570
# epoch=95	train loss=1.091551	train accuracy=0.673	test accuracy=0.507
# epoch=96	train loss=1.092474	train accuracy=0.663	test accuracy=0.447
# epoch=97	train loss=1.093612	train accuracy=0.654	test accuracy=0.517
# epoch=98	train loss=1.098311	train accuracy=0.640	test accuracy=0.613
# epoch=99	train loss=1.058693	train accuracy=0.665	test accuracy=0.497
# epoch=100	train loss=1.055195	train accuracy=0.667	test accuracy=0.363
# epoch=101	train loss=1.070299	train accuracy=0.673	test accuracy=0.097
# epoch=102	train loss=1.048023	train accuracy=0.665	test accuracy=0.357
# epoch=103	train loss=1.021831	train accuracy=0.691	test accuracy=0.477
