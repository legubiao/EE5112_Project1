# %% [markdown]
# # Task 1: Understand body language by gesture recognition with fully connected neural network

# %% [markdown]
# ## 1. Do literature search on gesture recognition and its application in Human-Robot Interaction. Summarize what you have learned.

# %% [markdown]
# ## 2. Referring to the previous example about building a neural network based classifier, use what you have learned to read the code for gesture classification below and design your own network architecture using fully connected layers.

# %% [markdown]
# ## 3. Run the model. Analyse and comment on the performance of your model based on fully connected layers.

# %%
import cv2
import numpy as np
import os
import itertools
import torch.utils.data as utils_data

# %% [markdown]
# ## 1) data preprocessing

# %% [markdown]
# Define a function to preprocess the images including resizing and binaryzation

# %%
def processSkinImage(filePath, resize_HW=48):
    # step 1
    # read the image
    original = cv2.imread(filename=filePath)

    # step 2
    # resize the image to
    image_resized = cv2.resize(original, (resize_HW, resize_HW))

    # step 3
    # convert the image from rgb to YCbCr
    image_ycbcr = cv2.cvtColor(image_resized, cv2.COLOR_BGR2YCR_CB)

    # step 4
    # get the central color of the image
    # expected the hand to be in the central of the image
    Cb_center_color = image_ycbcr[int(resize_HW/2), int(resize_HW/2), 1]
    Cr_center_color = image_ycbcr[int(resize_HW/2), int(resize_HW/2), 2]
    # set the range
    Cb_Difference = 15
    Cr_Difference = 10

    # step 5
    # detect skin pixels
    Cb = image_ycbcr[:, :, 1]
    Cr = image_ycbcr[:, :, 2]
    index = np.where((Cb >= Cb_center_color-Cb_Difference) & (Cb <= Cb_center_color+Cb_Difference)
                     & (Cr >= Cr_center_color-Cr_Difference) & (Cr <= Cr_center_color+Cr_Difference))

    # Mark detected pixels and output
    image_output = np.zeros((resize_HW, resize_HW))
    image_output[index] = 255

    # show image
    # cv2.imshow("", image_output)
    # cv2.waitKey(0)
    
    return image_output

# %% [markdown]
# Deal with all the images using the function defined above.
# The processed data is stored in a new folder 'dataset_processed'.
#
# Generate labels for each class. (class 0, 1, ..., num_classes)

# %%
path = './dataset/images'
path_processed = './dataset_processed/images'

# -------------------images processing--------------
for mainDir, subDir, fileList in os.walk(path):
    for file in fileList:
        currentPath = os.path.join(mainDir, file)
        processedImage = processSkinImage(currentPath)

        new_mainDir = path_processed + mainDir.split(path)[-1]
        if not os.path.exists(new_mainDir):
            os.makedirs(new_mainDir)
        cv2.imwrite(os.path.join(new_mainDir, file), processedImage)

# -----------------label generation----------------
label_path = './dataset_processed/labels'
if not os.path.exists(label_path):
    os.makedirs(label_path)

files = os.listdir(path)
for i, file in enumerate(files):
    subclass_label_path = os.path.join(label_path, file+'.txt')
    with open(subclass_label_path, 'w') as f:
        f.write('#label\n')
    for _ in range(len(os.listdir(os.path.join(path_processed, file)))):
        with open(subclass_label_path, 'a') as f:
            f.write('{:d}\n'.format(i))
    f.close()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 8
#       6 for file in fileList:
#       7     currentPath = os.path.join(mainDir, file)
# ----> 8     processedImage = processSkinImage(currentPath)
#      10     new_mainDir = path_processed + mainDir.split(path)[-1]
#      11     if not os.path.exists(new_mainDir):
#
# Cell In[2], line 8, in processSkinImage(filePath, resize_HW)
#       4 original = cv2.imread(filename=filePath)
#       6 # step 2
#       7 # resize the image to
# ----> 8 image_resized = cv2.resize(original, (resize_HW, resize_HW))
#      10 # step 3
#      11 # convert the image from rgb to YCbCr
#      12 image_ycbcr = cv2.cvtColor(image_resized, cv2.COLOR_BGR2YCR_CB)
#
# error: OpenCV(4.8.0) /Users/xperience/GHA-OpenCV-Python/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# ## 2) load data

# %%
Image = []
path_images = './dataset_processed/images'
for mainDir, subDir, fileList in os.walk(path_images):
    for file in fileList:
        currentPath = os.path.join(mainDir, file)
        Image.append(cv2.imread(currentPath)[:, :, 0])
Image = np.array(Image)
dataset_size, H, W = Image.shape
# for FCNN model, the image need to be stretched into one dimension: (b, h, w)->(b, h*w)
Image = Image.reshape(dataset_size, -1)


Label = []
path_labels = './dataset_processed/labels'
for file in os.listdir(path_labels):
    Label.append(np.loadtxt(os.path.join(path_labels, file)))
Label = np.array(list(itertools.chain.from_iterable(Label)))
num_classes = int(np.max(Label))+1

# %% [markdown]
# ## 3) build your own neural network based on fully connected layers.

# %% [markdown]
# Design the neural network architecture

# %%
import torch.nn as nn

class FCNNModel(nn.Module):
    def __init__(self, input_layer_size, hidden_layer_size, num_classes):
        super(FCNNModel, self).__init__()
        self.fc1 = nn.Linear(input_layer_size, hidden_layer_size)
        self.fc2 = nn.Linear(hidden_layer_size, num_classes)
        # code by yourself
        self.relu = nn.ReLU()

    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x
        # code by yourself

# %% [markdown]
# instantiate your model, set a optimizer and define a loss function.

# %%
import torch.optim as optim

model = FCNNModel(input_layer_size=H*W, hidden_layer_size=int(H*W/2), num_classes=num_classes)
# if torch.cuda.is_available():
#     model = model.cuda()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
loss_func = nn.CrossEntropyLoss()

# %% [markdown]
# ## 4) train and test

# %% [markdown]
# Encapsulate data

# %%
import torch

dataset = utils_data.TensorDataset(torch.Tensor(Image), torch.LongTensor(Label))
split_ratio = 0.8
train_size = int(split_ratio * dataset_size)
test_size = dataset_size - train_size
train_set, test_set = utils_data.random_split(dataset, [train_size, test_size])
train_loader = utils_data.DataLoader(dataset=train_set, batch_size=8, shuffle=True)
test_loader = utils_data.DataLoader(dataset=test_set, batch_size=8, shuffle=True)
print('Data is ready!')
# Out:
# Data is ready!

# %% [markdown]
# The following is the training and testing process in detail.

# %%
best_accuracy = 0
for epoch in range(500):
    running_loss = 0.0
    train_acc = 0.0
    for step, (batch_image, batch_label) in enumerate(train_loader):
        model.train()
        # if torch.cuda.is_available():
        #     batch_image, batch_label = batch_image.cuda(), batch_label.cuda()
        batch_output = model(batch_image)
        batch_loss = loss_func(batch_output, batch_label)

        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()

        running_loss += batch_loss.item()

        # train accuracy
        _, train_predicted = torch.max(batch_output.data, 1)
        train_acc += (train_predicted == batch_label).sum().item()

    train_acc /= train_size
    running_loss /= (step+1)

    # ----------test----------
    model.eval()
    test_acc = 0.0
    for test_image, test_label in test_loader:
        test_output = model(test_image)
        _, predicted = torch.max(test_output.data, 1)
        test_acc += (predicted == test_label).sum().item()
    test_acc /= test_size

    print('epoch={:d}\ttrain loss={:.6f}\ttrain accuracy={:.3f}\ttest accuracy={:.3f}'.format(
        epoch, running_loss, train_acc, test_acc))

    if test_acc >= best_accuracy:
        save_path = './trained_models/'
        if not os.path.exists(save_path):
             os.makedirs(save_path)
        torch.save(model.state_dict(), './trained_models/FCNN_model.pkl')
        best_accuracy = test_acc
# Out:
# epoch=0	train loss=378.286875	train accuracy=0.242	test accuracy=0.875
# epoch=1	train loss=95.043324	train accuracy=0.710	test accuracy=0.875
# epoch=2	train loss=18.894134	train accuracy=0.774	test accuracy=0.875
# epoch=3	train loss=32.315509	train accuracy=0.742	test accuracy=0.812
# epoch=4	train loss=6.564349	train accuracy=0.935	test accuracy=0.938
# epoch=5	train loss=3.658256	train accuracy=0.952	test accuracy=0.875
# epoch=6	train loss=2.024286	train accuracy=0.903	test accuracy=0.938
# epoch=7	train loss=0.266802	train accuracy=0.984	test accuracy=0.875
# epoch=8	train loss=0.450499	train accuracy=0.968	test accuracy=0.938
# epoch=9	train loss=0.696644	train accuracy=0.968	test accuracy=0.812
# epoch=10	train loss=0.525465	train accuracy=0.984	test accuracy=0.938
# epoch=11	train loss=1.399021	train accuracy=0.968	test accuracy=0.812
# epoch=12	train loss=0.859764	train accuracy=0.952	test accuracy=0.938
# epoch=13	train loss=2.756449	train accuracy=0.952	test accuracy=0.875
# epoch=14	train loss=2.806449	train accuracy=0.952	test accuracy=0.875
# epoch=15	train loss=0.459879	train accuracy=0.984	test accuracy=0.938
# epoch=16	train loss=0.000016	train accuracy=1.000	test accuracy=0.875
# epoch=17	train loss=0.021135	train accuracy=0.984	test accuracy=0.812
# epoch=18	train loss=0.036276	train accuracy=0.968	test accuracy=1.000
# epoch=19	train loss=0.000031	train accuracy=1.000	test accuracy=0.938
# epoch=20	train loss=0.332351	train accuracy=0.984	test accuracy=0.812
# epoch=21	train loss=1.582814	train accuracy=0.968	test accuracy=0.938
# epoch=22	train loss=1.585015	train accuracy=0.952	test accuracy=0.938
# epoch=23	train loss=7.239919	train accuracy=0.919	test accuracy=0.938
# epoch=24	train loss=3.673730	train accuracy=0.935	test accuracy=1.000
# epoch=25	train loss=3.323869	train accuracy=0.935	test accuracy=0.750
# epoch=26	train loss=13.381798	train accuracy=0.919	test accuracy=0.875
# epoch=27	train loss=1.359749	train accuracy=0.968	test accuracy=0.875
# epoch=28	train loss=1.492751	train accuracy=0.968	test accuracy=0.875
# epoch=29	train loss=0.058525	train accuracy=0.984	test accuracy=0.938
# epoch=30	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=31	train loss=0.314780	train accuracy=0.984	test accuracy=0.938
# epoch=32	train loss=0.000000	train accuracy=1.000	test accuracy=0.812
# epoch=33	train loss=0.368728	train accuracy=0.984	test accuracy=0.875
# epoch=34	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=35	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=36	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=37	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=38	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=39	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=40	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=41	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=42	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=43	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=44	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=45	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=46	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=47	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=48	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=49	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=50	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=51	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=52	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=53	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=54	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=55	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=56	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=57	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=58	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=59	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=60	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=61	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=62	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=63	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=64	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=65	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=66	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=67	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=68	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=69	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=70	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=71	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=72	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=73	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=74	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=75	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=76	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=77	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=78	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=79	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=80	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=81	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=82	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=83	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=84	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=85	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=86	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=87	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=88	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=89	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=90	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=91	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=92	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=93	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=94	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=95	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=96	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=97	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=98	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=99	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=100	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=101	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=102	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=103	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=104	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=105	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=106	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=107	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=108	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=109	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=110	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=111	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=112	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=113	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch=114	train loss=0.000000	train accuracy=1.000	test accuracy=0.938
# epoch